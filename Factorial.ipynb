# %%
num = int(input("Enter a number: "))
product = 1
for x in range(1, num + 1):
  product *= x
print("The factorial of %d is %d" % (num, product))
# Out:
# Enter a number: 4
# The factorial of 4 is 24
