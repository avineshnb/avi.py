# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from getpass import getpass
import os

token = getpass('Enter your GitHub token: ')
os.environ['GITHUB_TOKEN'] = token
# Out:
# Enter your GitHub token: ··········

# %%
# !mkdir -p /content/avi.py
# !cp /content/drive/MyDrive/Python/Python\ Task/*.ipynb /content/avi.py/

# %%
# !rm -rf /content/avi.py/.git

# %%
# %cd /content/avi.py

# !git init
# !git checkout -b main
# !git config --global user.email "avineshnattamai@gmail.com"
# !git config --global user.name "avineshnb"
# !git remote add origin https://avineshnb:$GITHUB_TOKEN@github.com/avineshnb/avi.py.git
# Out:
# /content/avi.py
# hint: Using 'master' as the name for the initial branch. This default branch name
# hint: is subject to change. To configure the initial branch name to use in all
# hint: of your new repositories, which will suppress this warning, call:
# hint:
# hint: 	git config --global init.defaultBranch <name>
# hint:
# hint: Names commonly chosen instead of 'master' are 'main', 'trunk' and
# hint: 'development'. The just-created branch can be renamed via this command:
# hint:
# hint: 	git branch -m <name>
# Initialized empty Git repository in /content/avi.py/.git/
# Switched to a new branch 'main'

# %%
# !git add .
# !git commit -m "Initial upload from Colab"
# Out:
# [main (root-commit) de5fa1c] Initial upload from Colab
#  11 files changed, 11 insertions(+)
#  create mode 100644 Array.ipynb
#  create mode 100644 Average.ipynb
#  create mode 100644 Factorial.ipynb
#  create mode 100644 Fibonacci Sequence.ipynb
#  create mode 100644 Github.ipynb
#  create mode 100644 Inequality.ipynb
#  create mode 100644 Multiplication Table.ipynb
#  create mode 100644 Number Data.ipynb
#  create mode 100644 Number Guessing Game.ipynb
#  create mode 100644 Parity.ipynb
#  create mode 100644 Prime.ipynb

# %%
# !git push -u origin main --force
# Out:
# fatal: not a git repository (or any of the parent directories): .git
