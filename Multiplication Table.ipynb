# %%
a, b = int(input("Enter a number: ")), int(input("Enter a number: "))
for x in range(b + 1):
  print("%d*%d=%d" % (a, x, a * x))
# Out:
# Enter a number: 10
# Enter a number: 9
# 10*0=0
# 10*1=10
# 10*2=20
# 10*3=30
# 10*4=40
# 10*5=50
# 10*6=60
# 10*7=70
# 10*8=80
# 10*9=90
