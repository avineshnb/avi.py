# %%
a, b = int(input("Enter your first number: ")), int(input("Enter your second number: "))
print("The average of %d and %d is %d." % (a, b, (a + b) / 2))
# Out:
# Enter your first number: 100
# Enter your second number: 90
# The average of 100 and 90 is 95.
